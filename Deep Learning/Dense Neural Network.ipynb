# %% [markdown]
# # Deep Learning (Dense Neural Network )

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.utils import class_weight

import tensorflow as tf
from tensorflow import keras
from keras import layers

# %% [markdown]
# ### Data Setup

# %%
# Read dataset and create training an validation datasets
training_set = pd.read_csv('../Data/train.csv')
training_set = training_set.drop(columns=["id"])
training_set["defects"] = [1 if value else 0 for value in training_set["defects"].values]

# %%
true_data = training_set[training_set["defects"].values == True]
false_data = training_set[training_set["defects"].values == False]

true_feature_data = true_data.drop(columns=["defects"])
false_feature_data = false_data.drop(columns=["defects"])

true_train_proportion = 0.5
false_train_proportion = true_train_proportion # * len(true_feature_data) / len(false_feature_data)

true_X_train, true_X_validation, true_Y_train, true_Y_validation = train_test_split(true_feature_data, true_data["defects"], test_size=(1-true_train_proportion))
false_X_train, false_X_validation, false_Y_train, false_Y_validation = train_test_split(false_feature_data, false_data["defects"], test_size=(1-false_train_proportion))

X_train = pd.concat([true_X_train, false_X_train])
X_validation = pd.concat([true_X_validation, false_X_validation])
Y_train = pd.concat([true_Y_train, false_Y_train])
Y_validation = pd.concat([true_Y_validation, false_Y_validation])

# %%
X_train = X_train.to_numpy().tolist()
X_validation = X_validation.to_numpy().tolist()
Y_train = Y_train.to_numpy().tolist()
Y_validation = Y_validation.to_numpy().tolist()

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Model Architecture

# %%
def build_model():

    inputs = keras.Input(shape=(21))
    x = inputs
    
    x = layers.Dense(32, activation=layers.LeakyReLU(0.5))(x)
    x = layers.Dropout(0.2)(x)

    x = layers.Dense(64, activation=layers.LeakyReLU(0.5))(x)
    x = layers.Dropout(0.2)(x)

    x = layers.Dense(32, activation=layers.LeakyReLU(0.5))(x)
    x = layers.Dropout(0.2)(x)

    x = layers.Dense(8, activation=layers.LeakyReLU(0.5))(x)
    x = layers.Dropout(0.2)(x)

    x = layers.Dense(1, activation="sigmoid")(x)

    outputs = x
    model = keras.Model(inputs=inputs, outputs=outputs)

    return model

# Define model's architecture
model = build_model()

# Print model's architecture
model.summary()
# Out:
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_19 (InputLayer)       [(None, 21)]              0
#
#  dense_88 (Dense)            (None, 32)                704
#
#  dropout_70 (Dropout)        (None, 32)                0
#
#  dense_89 (Dense)            (None, 64)                2112
#
#  dropout_71 (Dropout)        (None, 64)                0
#
#  dense_90 (Dense)            (None, 32)                2080
#
#  dropout_72 (Dropout)        (None, 32)                0
#
#  dense_91 (Dense)            (None, 8)                 264
#
#  dropout_73 (Dropout)        (None, 8)                 0
#
#  dense_92 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 5,169
# Trainable params: 5,169
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Training

# %%
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(training_set["defects"]), y=training_set["defects"])
# class_weights = [0.6,2] -- 0.55
class_weights = [0.6,1.8]
class_weight_dict = {}
for i in range(len(class_weights)):
    class_weight_dict[i] = class_weights[i]*(1+i)
    
print("Training class weights:", class_weight_dict)
# Out:
# Training class weights: {0: 0.6, 1: 1.8}

# %%
validation_class_weights = np.array([ class_weight_dict[value] for value in Y_validation])
print(len(validation_class_weights))
# Out:
# 50882

# %%
checkpoint_filepath = './defects.h5'
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(checkpoint_filepath, save_best_only=True)

# Define early stop callback
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)


# Add optimizers and evaluation metrics to model
model.compile(
    optimizer=tf.keras.optimizers.Adam(2e-4, beta_1=0.5),
    # optimizer=keras.optimizers.SGD(learning_rate=0.00125),
    loss=keras.losses.BinaryCrossentropy(),
    # loss=tf.keras.losses.BinaryCrossentropy(),
    weighted_metrics=[
             keras.metrics.BinaryAccuracy(),
             keras.metrics.Precision(name="precision"),
             keras.metrics.Recall(name="recall")
             ],
)

# Train model
history = model.fit(
    X_train,
    Y_train,
    epochs=30,
    class_weight=class_weight_dict,
    validation_data=(X_validation, Y_validation, validation_class_weights),
    # validation_data=(X_validation, Y_validation),
    callbacks=[checkpoint_cb, early_stopping_cb]
    # callbacks=[checkpoint_cb]
)
# Out:
# Epoch 1/30
# 1591/1591 [==============================] - 26s 16ms/step - loss: 25.2458 - binary_accuracy: 0.5931 - precision: 0.5654 - recall: 0.5630 - val_loss: 6.9633 - val_binary_accuracy: 0.6504 - val_precision: 0.6288 - val_recall: 0.6166
# Epoch 2/30
# 1591/1591 [==============================] - 10s 6ms/step - loss: 19.3989 - binary_accuracy: 0.6003 - precision: 0.5733 - recall: 0.5702 - val_loss: 5.4677 - val_binary_accuracy: 0.6715 - val_precision: 0.6639 - val_recall: 0.6032
# Epoch 3/30
# 1591/1591 [==============================] - 11s 7ms/step - loss: 22.5172 - binary_accuracy: 0.6114 - precision: 0.5886 - recall: 0.5631 - val_loss: 4.6936 - val_binary_accuracy: 0.6868 - val_precision: 0.6880 - val_recall: 0.6048
# Epoch 4/30
# 1591/1591 [==============================] - 11s 7ms/step - loss: 12.7867 - binary_accuracy: 0.6159 - precision: 0.5927 - recall: 0.5723 - val_loss: 4.4757 - val_binary_accuracy: 0.6873 - val_precision: 0.6825 - val_recall: 0.6203
# Epoch 5/30
# 1591/1591 [==============================] - 11s 7ms/step - loss: 11.4977 - binary_accuracy: 0.6131 - precision: 0.5971 - recall: 0.5319 - val_loss: 4.4031 - val_binary_accuracy: 0.6750 - val_precision: 0.6714 - val_recall: 0.5977
# Epoch 6/30
# 1591/1591 [==============================] - 12s 8ms/step - loss: 10.6486 - binary_accuracy: 0.6120 - precision: 0.5988 - recall: 0.5170 - val_loss: 3.3281 - val_binary_accuracy: 0.6803 - val_precision: 0.6956 - val_recall: 0.5631
# Epoch 7/30
# 1591/1591 [==============================] - 11s 7ms/step - loss: 6.6338 - binary_accuracy: 0.5973 - precision: 0.5783 - recall: 0.5147 - val_loss: 1.8669 - val_binary_accuracy: 0.6687 - val_precision: 0.7336 - val_recall: 0.4582
# Epoch 8/30
# 1591/1591 [==============================] - 10s 6ms/step - loss: 6.5484 - binary_accuracy: 0.6011 - precision: 0.5865 - recall: 0.4997 - val_loss: 1.9352 - val_binary_accuracy: 0.6691 - val_precision: 0.7351 - val_recall: 0.4577
# Epoch 9/30
# 1591/1591 [==============================] - 11s 7ms/step - loss: 6.0226 - binary_accuracy: 0.5956 - precision: 0.5758 - recall: 0.5150 - val_loss: 1.8681 - val_binary_accuracy: 0.6609 - val_precision: 0.7593 - val_recall: 0.4030
# Epoch 10/30
# 1591/1591 [==============================] - 12s 7ms/step - loss: 4.4412 - binary_accuracy: 0.6013 - precision: 0.5885 - recall: 0.4912 - val_loss: 1.5159 - val_binary_accuracy: 0.6667 - val_precision: 0.7767 - val_recall: 0.4035
# Epoch 11/30
# 1591/1591 [==============================] - 12s 8ms/step - loss: 3.3201 - binary_accuracy: 0.5946 - precision: 0.5764 - recall: 0.5033 - val_loss: 0.9583 - val_binary_accuracy: 0.6470 - val_precision: 0.7969 - val_recall: 0.3295
# Epoch 12/30
# 1591/1591 [==============================] - 13s 8ms/step - loss: 2.7454 - binary_accuracy: 0.5893 - precision: 0.5728 - recall: 0.4808 - val_loss: 1.0495 - val_binary_accuracy: 0.6612 - val_precision: 0.7637 - val_recall: 0.3993
# Epoch 13/30
# 1591/1591 [==============================] - 13s 8ms/step - loss: 2.1717 - binary_accuracy: 0.5916 - precision: 0.5731 - recall: 0.4985 - val_loss: 0.8394 - val_binary_accuracy: 0.6611 - val_precision: 0.7897 - val_recall: 0.3756
# Epoch 14/30
# 1591/1591 [==============================] - 11s 7ms/step - loss: 2.2253 - binary_accuracy: 0.6124 - precision: 0.6040 - recall: 0.4980 - val_loss: 0.8160 - val_binary_accuracy: 0.6680 - val_precision: 0.7848 - val_recall: 0.4000
# Epoch 15/30
# 1591/1591 [==============================] - 11s 7ms/step - loss: 1.4849 - binary_accuracy: 0.6068 - precision: 0.5959 - recall: 0.4958 - val_loss: 0.7067 - val_binary_accuracy: 0.6715 - val_precision: 0.7958 - val_recall: 0.4007
# Epoch 16/30
# 1591/1591 [==============================] - 12s 7ms/step - loss: 1.1389 - binary_accuracy: 0.6152 - precision: 0.6098 - recall: 0.4931 - val_loss: 0.6531 - val_binary_accuracy: 0.6835 - val_precision: 0.7817 - val_recall: 0.4488
# Epoch 17/30
# 1591/1591 [==============================] - 11s 7ms/step - loss: 1.3978 - binary_accuracy: 0.6193 - precision: 0.6146 - recall: 0.4996 - val_loss: 0.7007 - val_binary_accuracy: 0.6660 - val_precision: 0.7766 - val_recall: 0.4017
# Epoch 18/30
# 1591/1591 [==============================] - 10s 7ms/step - loss: 1.2214 - binary_accuracy: 0.6208 - precision: 0.6277 - recall: 0.4659 - val_loss: 0.6433 - val_binary_accuracy: 0.6688 - val_precision: 0.7802 - val_recall: 0.4065
# Epoch 19/30
# 1591/1591 [==============================] - 10s 6ms/step - loss: 1.0578 - binary_accuracy: 0.6278 - precision: 0.6409 - recall: 0.4651 - val_loss: 0.6099 - val_binary_accuracy: 0.6471 - val_precision: 0.8173 - val_recall: 0.3165
# Epoch 20/30
# 1591/1591 [==============================] - 10s 6ms/step - loss: 0.7908 - binary_accuracy: 0.6309 - precision: 0.6628 - recall: 0.4298 - val_loss: 0.5890 - val_binary_accuracy: 0.6351 - val_precision: 0.8367 - val_recall: 0.2733
# Epoch 21/30
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.7552 - binary_accuracy: 0.6406 - precision: 0.6825 - recall: 0.4333 - val_loss: 0.5777 - val_binary_accuracy: 0.6499 - val_precision: 0.8354 - val_recall: 0.3134
# Epoch 22/30
# 1591/1591 [==============================] - 12s 7ms/step - loss: 0.7055 - binary_accuracy: 0.6443 - precision: 0.6894 - recall: 0.4364 - val_loss: 0.5730 - val_binary_accuracy: 0.6443 - val_precision: 0.8289 - val_recall: 0.3019
# Epoch 23/30
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.6898 - binary_accuracy: 0.6445 - precision: 0.7056 - recall: 0.4121 - val_loss: 0.5724 - val_binary_accuracy: 0.6389 - val_precision: 0.8433 - val_recall: 0.2802
# Epoch 24/30
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.6097 - binary_accuracy: 0.6544 - precision: 0.7165 - recall: 0.4324 - val_loss: 0.5496 - val_binary_accuracy: 0.6754 - val_precision: 0.8305 - val_recall: 0.3848
# Epoch 25/30
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.6116 - binary_accuracy: 0.6601 - precision: 0.7311 - recall: 0.4325 - val_loss: 0.5699 - val_binary_accuracy: 0.6574 - val_precision: 0.8235 - val_recall: 0.3406
# Epoch 26/30
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.5729 - binary_accuracy: 0.6661 - precision: 0.7303 - recall: 0.4540 - val_loss: 0.5518 - val_binary_accuracy: 0.6815 - val_precision: 0.8154 - val_recall: 0.4126
# Epoch 27/30
# 1591/1591 [==============================] - 12s 8ms/step - loss: 0.5856 - binary_accuracy: 0.6661 - precision: 0.7463 - recall: 0.4339 - val_loss: 0.5535 - val_binary_accuracy: 0.6390 - val_precision: 0.8564 - val_recall: 0.2744
# Epoch 28/30
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.5714 - binary_accuracy: 0.6653 - precision: 0.7552 - recall: 0.4212 - val_loss: 0.5420 - val_binary_accuracy: 0.6932 - val_precision: 0.8081 - val_recall: 0.4514
# Epoch 29/30
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.5673 - binary_accuracy: 0.6741 - precision: 0.7369 - recall: 0.4721 - val_loss: 0.5379 - val_binary_accuracy: 0.6967 - val_precision: 0.8063 - val_recall: 0.4629
# Epoch 30/30
# 1591/1591 [==============================] - 13s 8ms/step - loss: 0.5575 - binary_accuracy: 0.6783 - precision: 0.7564 - recall: 0.4608 - val_loss: 0.5260 - val_binary_accuracy: 0.7217 - val_precision: 0.7583 - val_recall: 0.5946

# %%
graph_metrics = ["precision", "recall", "binary_accuracy", "loss"]
# graph_metrics = ["binary_accuracy", "loss"]

max_loss = max(history.history["loss"])
max_val_loss = max(history.history["val_loss"])
y_max = [1, 1, 1, max(max_loss, max_val_loss)]

fig, ax = plt.subplots(1, len(graph_metrics), figsize=(16, 4))
ax = ax.ravel()

for i, metric in enumerate(graph_metrics):
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model " + metric)
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["Training", "Validation"])
    ax[i].set_ylim(ymin=0, ymax=1.1*y_max[i])

# %%
# Reload best model
best_model = keras.models.load_model(checkpoint_filepath)

# %%
validation_predictions = best_model.predict(X_validation)
# validation_predictions = model.predict(X_validation)
validation_prediction_labels = [round(item[0]) for item in validation_predictions.tolist()]


conf_matrix = confusion_matrix(list(Y_validation), validation_prediction_labels, labels=[False, True])

recall_true = conf_matrix[1][1] / (conf_matrix[1][0] + conf_matrix[1][1])
precision_true = conf_matrix[1][1] / (conf_matrix[0][1] + conf_matrix[1][1])
F1_true = 2 * ( (precision_true * recall_true) / (precision_true + recall_true) )

correct_vals = conf_matrix[0][0] + conf_matrix[1][1]
incorrect_vals = conf_matrix[0][1] + conf_matrix[1][0]
accuracy = correct_vals / (correct_vals + incorrect_vals)

print("Correctly predicted labelss: ", correct_vals)
print("Incorrectly predicted labelss: ", incorrect_vals)
print("Model's accuracy: ", accuracy)
print("Model's recall: ", recall_true)
print("Model's precision: ", precision_true)
print("Model's F1 score: ", F1_true)
# Out:
# 1591/1591 [==============================] - 1s 831us/step
# Correctly predicted labelss:  39652
# Incorrectly predicted labelss:  11230
# Model's accuracy:  0.7792932667741048
# Model's recall:  0.5946063128685397
# Model's precision:  0.5112585744109752
# Model's F1 score:  0.5497915330339961

# %%
# Plot confusion Matrix
fig, ax = plt.subplots()
ax.matshow(conf_matrix, cmap='tab20c')

# Print classification counts within matrix boxes
for i in range(len(conf_matrix)):
   for j in range(len(conf_matrix[0])):
      c = conf_matrix[j, i]
      ax.text(i, j, str(c), va='center', ha='center')

# Set plot axis titles and show plot
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Classification Counts')
plt.show()

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Calculate scores for testing dataset
fpr, tpr, thresholds = roc_curve(list(Y_validation), validation_prediction_labels)

# Calculate AUC score
auc_score = roc_auc_score(list(Y_validation), validation_prediction_labels)

# Print ROC plot
plt.plot(fpr, tpr,)
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(["AUC score: " + str(round(auc_score, 5))], loc="best")
plt.show()
