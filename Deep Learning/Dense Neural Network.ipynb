# %% [markdown]
# # Deep Learning (Dense Neural Network )

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.utils import class_weight

import tensorflow as tf
from tensorflow import keras
from keras import layers

# %% [markdown]
# ### Data Setup

# %%
# Read dataset and create training an validation datasets
training_set = pd.read_csv('../Data/train.csv')
training_set = training_set.drop(columns=["id"])
training_set["defects"] = [1 if value else 0 for value in training_set["defects"].values]

# %%
true_data = training_set[training_set["defects"].values == True]
false_data = training_set[training_set["defects"].values == False]

true_feature_data = true_data.drop(columns=["defects"])
false_feature_data = false_data.drop(columns=["defects"])

true_train_proportion = 0.5
false_train_proportion = true_train_proportion # * len(true_feature_data) / len(false_feature_data)

true_X_train, true_X_validation, true_Y_train, true_Y_validation = train_test_split(true_feature_data, true_data["defects"], test_size=(1-true_train_proportion))
false_X_train, false_X_validation, false_Y_train, false_Y_validation = train_test_split(false_feature_data, false_data["defects"], test_size=(1-false_train_proportion))

X_train = pd.concat([true_X_train, false_X_train])
X_validation = pd.concat([true_X_validation, false_X_validation])
Y_train = pd.concat([true_Y_train, false_Y_train])
Y_validation = pd.concat([true_Y_validation, false_Y_validation])

# %%
X_train = X_train.to_numpy().tolist()
X_validation = X_validation.to_numpy().tolist()
Y_train = Y_train.to_numpy().tolist()
Y_validation = Y_validation.to_numpy().tolist()

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Model Architecture

# %%
def build_model():

    inputs = keras.Input(shape=(21))
    x = inputs
    
    x = layers.Dense(32, activation=layers.LeakyReLU(0.5))(x)
    x = layers.Dropout(0.2)(x)

    x = layers.Dense(64, activation=layers.LeakyReLU(0.5))(x)
    x = layers.Dropout(0.2)(x)

    x = layers.Dense(32, activation=layers.LeakyReLU(0.5))(x)
    x = layers.Dropout(0.2)(x)

    x = layers.Dense(8, activation=layers.LeakyReLU(0.5))(x)
    x = layers.Dropout(0.2)(x)

    x = layers.Dense(1, activation="sigmoid")(x)

    outputs = x
    model = keras.Model(inputs=inputs, outputs=outputs)

    return model

# Define model's architecture
model = build_model()

# Print model's architecture
model.summary()
# Out:
# Model: "model_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_24 (InputLayer)       [(None, 21)]              0
#
#  dense_113 (Dense)           (None, 32)                704
#
#  dropout_90 (Dropout)        (None, 32)                0
#
#  dense_114 (Dense)           (None, 64)                2112
#
#  dropout_91 (Dropout)        (None, 64)                0
#
#  dense_115 (Dense)           (None, 32)                2080
#
#  dropout_92 (Dropout)        (None, 32)                0
#
#  dense_116 (Dense)           (None, 8)                 264
#
#  dropout_93 (Dropout)        (None, 8)                 0
#
#  dense_117 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 5,169
# Trainable params: 5,169
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Training

# %%
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(training_set["defects"]), y=training_set["defects"])
# class_weights = [0.6,2] -- 0.55
class_weights = [0.6,1.8]
class_weight_dict = {}
for i in range(len(class_weights)):
    class_weight_dict[i] = class_weights[i]
    
print("Training class weights:", class_weight_dict)
# Out:
# Training class weights: {0: 0.6, 1: 1.8}

# %%
validation_class_weights = np.array([ class_weight_dict[value] for value in Y_validation])
print(len(validation_class_weights))
# Out:
# 50882

# %%
checkpoint_filepath = './defects.h5'
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(checkpoint_filepath, save_best_only=True)

# Define early stop callback
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)


# Add optimizers and evaluation metrics to model
model.compile(
    optimizer=tf.keras.optimizers.Adam(2e-4, beta_1=0.5),
    # optimizer=keras.optimizers.SGD(learning_rate=0.00125),
    loss=keras.losses.BinaryCrossentropy(),
    # loss=tf.keras.losses.BinaryCrossentropy(),
    weighted_metrics=[
             keras.metrics.BinaryAccuracy(),
             keras.metrics.Precision(name="precision"),
             keras.metrics.Recall(name="recall")
             ],
)

# Train model
history = model.fit(
    X_train,
    Y_train,
    epochs=50,
    class_weight=class_weight_dict,
    validation_data=(X_validation, Y_validation, validation_class_weights),
    # validation_data=(X_validation, Y_validation),
    callbacks=[checkpoint_cb, early_stopping_cb]
    # callbacks=[checkpoint_cb]
)
# Out:
# Epoch 1/50
# 1591/1591 [==============================] - 26s 16ms/step - loss: 661.3164 - binary_accuracy: 0.4830 - precision: 0.4628 - recall: 0.6521 - val_loss: 257.7261 - val_binary_accuracy: 0.4520 - val_precision: 0.4521 - val_recall: 0.8087
# Epoch 2/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 369.1961 - binary_accuracy: 0.5156 - precision: 0.4872 - recall: 0.6733 - val_loss: 133.7096 - val_binary_accuracy: 0.5510 - val_precision: 0.5123 - val_recall: 0.8357
# Epoch 3/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 214.4618 - binary_accuracy: 0.5452 - precision: 0.5111 - recall: 0.6446 - val_loss: 108.8280 - val_binary_accuracy: 0.5385 - val_precision: 0.5040 - val_recall: 0.8477
# Epoch 4/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 157.4886 - binary_accuracy: 0.5619 - precision: 0.5270 - recall: 0.6215 - val_loss: 51.9799 - val_binary_accuracy: 0.6245 - val_precision: 0.5702 - val_recall: 0.8014
# Epoch 5/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 128.0949 - binary_accuracy: 0.5832 - precision: 0.5490 - recall: 0.6119 - val_loss: 35.2315 - val_binary_accuracy: 0.6656 - val_precision: 0.6189 - val_recall: 0.7424
# Epoch 6/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 88.2099 - binary_accuracy: 0.5922 - precision: 0.5614 - recall: 0.5869 - val_loss: 62.9629 - val_binary_accuracy: 0.6364 - val_precision: 0.5884 - val_recall: 0.7418
# Epoch 7/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 90.3080 - binary_accuracy: 0.5943 - precision: 0.5650 - recall: 0.5775 - val_loss: 30.0139 - val_binary_accuracy: 0.6499 - val_precision: 0.6012 - val_recall: 0.7473
# Epoch 8/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 60.8414 - binary_accuracy: 0.6008 - precision: 0.5744 - recall: 0.5669 - val_loss: 16.8847 - val_binary_accuracy: 0.6755 - val_precision: 0.6307 - val_recall: 0.7393
# Epoch 9/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 43.5956 - binary_accuracy: 0.5981 - precision: 0.5730 - recall: 0.5536 - val_loss: 14.4635 - val_binary_accuracy: 0.6674 - val_precision: 0.6292 - val_recall: 0.7039
# Epoch 10/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 32.9305 - binary_accuracy: 0.5986 - precision: 0.5764 - recall: 0.5359 - val_loss: 11.9501 - val_binary_accuracy: 0.6506 - val_precision: 0.6200 - val_recall: 0.6537
# Epoch 11/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 31.7432 - binary_accuracy: 0.5993 - precision: 0.5749 - recall: 0.5511 - val_loss: 13.0096 - val_binary_accuracy: 0.6723 - val_precision: 0.6333 - val_recall: 0.7115
# Epoch 12/50
# 1591/1591 [==============================] - 10s 6ms/step - loss: 22.6356 - binary_accuracy: 0.6147 - precision: 0.5959 - recall: 0.5480 - val_loss: 5.7463 - val_binary_accuracy: 0.6911 - val_precision: 0.6531 - val_recall: 0.7243
# Epoch 13/50
# 1591/1591 [==============================] - 10s 7ms/step - loss: 17.1261 - binary_accuracy: 0.6075 - precision: 0.5885 - recall: 0.5356 - val_loss: 6.3852 - val_binary_accuracy: 0.6800 - val_precision: 0.6346 - val_recall: 0.7446
# Epoch 14/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 14.0939 - binary_accuracy: 0.6094 - precision: 0.5918 - recall: 0.5325 - val_loss: 4.4504 - val_binary_accuracy: 0.6890 - val_precision: 0.6497 - val_recall: 0.7275
# Epoch 15/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 10.9636 - binary_accuracy: 0.6169 - precision: 0.5988 - recall: 0.5490 - val_loss: 4.8082 - val_binary_accuracy: 0.6942 - val_precision: 0.6624 - val_recall: 0.7065
# Epoch 16/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 9.5062 - binary_accuracy: 0.6166 - precision: 0.6010 - recall: 0.5371 - val_loss: 2.8445 - val_binary_accuracy: 0.7082 - val_precision: 0.6872 - val_recall: 0.6904
# Epoch 17/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 7.3133 - binary_accuracy: 0.6153 - precision: 0.5984 - recall: 0.5404 - val_loss: 2.3442 - val_binary_accuracy: 0.7044 - val_precision: 0.6696 - val_recall: 0.7269
# Epoch 18/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 6.4258 - binary_accuracy: 0.6183 - precision: 0.5958 - recall: 0.5731 - val_loss: 2.4143 - val_binary_accuracy: 0.7006 - val_precision: 0.6630 - val_recall: 0.7323
# Epoch 19/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 4.8247 - binary_accuracy: 0.6084 - precision: 0.5831 - recall: 0.5716 - val_loss: 1.5821 - val_binary_accuracy: 0.7085 - val_precision: 0.6801 - val_recall: 0.7114
# Epoch 20/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 3.3912 - binary_accuracy: 0.6080 - precision: 0.5854 - recall: 0.5558 - val_loss: 1.5428 - val_binary_accuracy: 0.7097 - val_precision: 0.7188 - val_recall: 0.6235
# Epoch 21/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 2.8195 - binary_accuracy: 0.6132 - precision: 0.5929 - recall: 0.5532 - val_loss: 1.5717 - val_binary_accuracy: 0.7103 - val_precision: 0.6903 - val_recall: 0.6908
# Epoch 22/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 2.6098 - binary_accuracy: 0.6195 - precision: 0.5977 - recall: 0.5714 - val_loss: 1.1574 - val_binary_accuracy: 0.7093 - val_precision: 0.6942 - val_recall: 0.6770
# Epoch 23/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 2.6081 - binary_accuracy: 0.6144 - precision: 0.5889 - recall: 0.5822 - val_loss: 1.1735 - val_binary_accuracy: 0.7145 - val_precision: 0.7367 - val_recall: 0.6065
# Epoch 24/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 1.7547 - binary_accuracy: 0.6221 - precision: 0.6071 - recall: 0.5451 - val_loss: 0.9353 - val_binary_accuracy: 0.7145 - val_precision: 0.7306 - val_recall: 0.6173
# Epoch 25/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 1.4559 - binary_accuracy: 0.6244 - precision: 0.6132 - recall: 0.5340 - val_loss: 0.8279 - val_binary_accuracy: 0.7157 - val_precision: 0.7480 - val_recall: 0.5915
# Epoch 26/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 1.5556 - binary_accuracy: 0.6227 - precision: 0.6125 - recall: 0.5269 - val_loss: 0.7602 - val_binary_accuracy: 0.7107 - val_precision: 0.7153 - val_recall: 0.6341
# Epoch 27/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 1.3012 - binary_accuracy: 0.6249 - precision: 0.6119 - recall: 0.5424 - val_loss: 0.8802 - val_binary_accuracy: 0.7167 - val_precision: 0.7449 - val_recall: 0.6000
# Epoch 28/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 1.0302 - binary_accuracy: 0.6317 - precision: 0.6324 - recall: 0.5082 - val_loss: 0.6773 - val_binary_accuracy: 0.7110 - val_precision: 0.7865 - val_recall: 0.5248
# Epoch 29/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 1.0493 - binary_accuracy: 0.6361 - precision: 0.6359 - recall: 0.5198 - val_loss: 0.6921 - val_binary_accuracy: 0.7040 - val_precision: 0.7798 - val_recall: 0.5118
# Epoch 30/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.8652 - binary_accuracy: 0.6453 - precision: 0.6646 - recall: 0.4880 - val_loss: 0.6825 - val_binary_accuracy: 0.6837 - val_precision: 0.8090 - val_recall: 0.4240
# Epoch 31/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.9633 - binary_accuracy: 0.6504 - precision: 0.6866 - recall: 0.4650 - val_loss: 0.6433 - val_binary_accuracy: 0.6926 - val_precision: 0.8017 - val_recall: 0.4557
# Epoch 32/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.7508 - binary_accuracy: 0.6515 - precision: 0.6844 - recall: 0.4736 - val_loss: 0.5756 - val_binary_accuracy: 0.6973 - val_precision: 0.8085 - val_recall: 0.4624
# Epoch 33/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.7389 - binary_accuracy: 0.6605 - precision: 0.6975 - recall: 0.4845 - val_loss: 0.6028 - val_binary_accuracy: 0.6863 - val_precision: 0.8019 - val_recall: 0.4375
# Epoch 34/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.6611 - binary_accuracy: 0.6583 - precision: 0.7182 - recall: 0.4436 - val_loss: 0.5709 - val_binary_accuracy: 0.6962 - val_precision: 0.8109 - val_recall: 0.4573
# Epoch 35/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.6461 - binary_accuracy: 0.6659 - precision: 0.7313 - recall: 0.4520 - val_loss: 0.5625 - val_binary_accuracy: 0.6900 - val_precision: 0.8226 - val_recall: 0.4302
# Epoch 36/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.6390 - binary_accuracy: 0.6684 - precision: 0.7462 - recall: 0.4415 - val_loss: 0.5551 - val_binary_accuracy: 0.6895 - val_precision: 0.8177 - val_recall: 0.4328
# Epoch 37/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.6216 - binary_accuracy: 0.6642 - precision: 0.7355 - recall: 0.4407 - val_loss: 0.5555 - val_binary_accuracy: 0.6921 - val_precision: 0.8215 - val_recall: 0.4368
# Epoch 38/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.5900 - binary_accuracy: 0.6657 - precision: 0.7494 - recall: 0.4290 - val_loss: 0.5402 - val_binary_accuracy: 0.6976 - val_precision: 0.8207 - val_recall: 0.4525
# Epoch 39/50
# 1591/1591 [==============================] - 12s 7ms/step - loss: 0.5537 - binary_accuracy: 0.6774 - precision: 0.7499 - recall: 0.4658 - val_loss: 0.5376 - val_binary_accuracy: 0.7161 - val_precision: 0.7937 - val_recall: 0.5311
# Epoch 40/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.5751 - binary_accuracy: 0.6685 - precision: 0.7678 - recall: 0.4179 - val_loss: 0.5368 - val_binary_accuracy: 0.6984 - val_precision: 0.8214 - val_recall: 0.4539
# Epoch 41/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.5599 - binary_accuracy: 0.6768 - precision: 0.7472 - recall: 0.4674 - val_loss: 0.5331 - val_binary_accuracy: 0.7152 - val_precision: 0.7985 - val_recall: 0.5232
# Epoch 42/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.5504 - binary_accuracy: 0.6837 - precision: 0.7564 - recall: 0.4779 - val_loss: 0.5291 - val_binary_accuracy: 0.6982 - val_precision: 0.8226 - val_recall: 0.4524
# Epoch 43/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.5753 - binary_accuracy: 0.6708 - precision: 0.7623 - recall: 0.4307 - val_loss: 0.5341 - val_binary_accuracy: 0.7111 - val_precision: 0.8007 - val_recall: 0.5091
# Epoch 44/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.5424 - binary_accuracy: 0.6857 - precision: 0.7532 - recall: 0.4882 - val_loss: 0.5284 - val_binary_accuracy: 0.7043 - val_precision: 0.8162 - val_recall: 0.4749
# Epoch 45/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.5553 - binary_accuracy: 0.6890 - precision: 0.7522 - recall: 0.5000 - val_loss: 0.5253 - val_binary_accuracy: 0.7173 - val_precision: 0.7894 - val_recall: 0.5398
# Epoch 46/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.5541 - binary_accuracy: 0.6845 - precision: 0.7660 - recall: 0.4688 - val_loss: 0.5208 - val_binary_accuracy: 0.7174 - val_precision: 0.7846 - val_recall: 0.5456
# Epoch 47/50
# 1591/1591 [==============================] - 12s 8ms/step - loss: 0.5415 - binary_accuracy: 0.6893 - precision: 0.7551 - recall: 0.4972 - val_loss: 0.5249 - val_binary_accuracy: 0.7037 - val_precision: 0.8087 - val_recall: 0.4801
# Epoch 48/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.5308 - binary_accuracy: 0.6937 - precision: 0.7520 - recall: 0.5152 - val_loss: 0.5145 - val_binary_accuracy: 0.7244 - val_precision: 0.7593 - val_recall: 0.6016
# Epoch 49/50
# 1591/1591 [==============================] - 13s 8ms/step - loss: 0.5596 - binary_accuracy: 0.6839 - precision: 0.7567 - recall: 0.4782 - val_loss: 0.5193 - val_binary_accuracy: 0.7159 - val_precision: 0.7972 - val_recall: 0.5266
# Epoch 50/50
# 1591/1591 [==============================] - 11s 7ms/step - loss: 0.5333 - binary_accuracy: 0.6955 - precision: 0.7532 - recall: 0.5194 - val_loss: 0.5369 - val_binary_accuracy: 0.7196 - val_precision: 0.7812 - val_recall: 0.5565

# %%
graph_metrics = ["precision", "recall", "binary_accuracy", "loss"]
# graph_metrics = ["binary_accuracy", "loss"]

max_loss = max(history.history["loss"])
max_val_loss = max(history.history["val_loss"])
y_max = [1, 1, 1, max(max_loss, max_val_loss)]

fig, ax = plt.subplots(1, len(graph_metrics), figsize=(16, 4))
ax = ax.ravel()

for i, metric in enumerate(graph_metrics):
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model " + metric)
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["Training", "Validation"])
    ax[i].set_ylim(ymin=0, ymax=1.1*y_max[i])

# %%
# Reload best model
best_model = keras.models.load_model(checkpoint_filepath)

# %%
validation_predictions = best_model.predict(X_validation)
# validation_predictions = model.predict(X_validation)
validation_prediction_labels = [round(item[0]) for item in validation_predictions.tolist()]


conf_matrix = confusion_matrix(list(Y_validation), validation_prediction_labels, labels=[False, True])

recall_true = conf_matrix[1][1] / (conf_matrix[1][0] + conf_matrix[1][1])
precision_true = conf_matrix[1][1] / (conf_matrix[0][1] + conf_matrix[1][1])
F1_true = 2 * ( (precision_true * recall_true) / (precision_true + recall_true) )

correct_vals = conf_matrix[0][0] + conf_matrix[1][1]
incorrect_vals = conf_matrix[0][1] + conf_matrix[1][0]
accuracy = correct_vals / (correct_vals + incorrect_vals)

print("Correctly predicted labelss: ", correct_vals)
print("Incorrectly predicted labelss: ", incorrect_vals)
print("Model's accuracy: ", accuracy)
print("Model's recall: ", recall_true)
print("Model's precision: ", precision_true)
print("Model's F1 score: ", F1_true)
# Out:
# 1591/1591 [==============================] - 2s 910us/step
# Correctly predicted labelss:  39690
# Incorrectly predicted labelss:  11192
# Model's accuracy:  0.7800400927636493
# Model's recall:  0.6016302462712453
# Model's precision:  0.5125591016548463
# Model's F1 score:  0.5535343864688049

# %%
# Plot confusion Matrix
fig, ax = plt.subplots()
ax.matshow(conf_matrix, cmap='tab20c')

# Print classification counts within matrix boxes
for i in range(len(conf_matrix)):
   for j in range(len(conf_matrix[0])):
      c = conf_matrix[j, i]
      ax.text(i, j, str(c), va='center', ha='center')

# Set plot axis titles and show plot
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Classification Counts')
plt.show()

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Calculate scores for testing dataset
fpr, tpr, thresholds = roc_curve(list(Y_validation), validation_prediction_labels)

# Calculate AUC score
auc_score = roc_auc_score(list(Y_validation), validation_prediction_labels)

# Print ROC plot
plt.plot(fpr, tpr,)
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(["AUC score: " + str(round(auc_score, 5))], loc="best")
plt.show()
